# %% [markdown]
# Houreyyy belajar KNN, bedanya knn sama k means, kalau knn udh punya labelnya yah

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\Ruang Lab\Kelas Machine Learning\kelasbagus3-deep-understanding-of-machine-learning\Data\iris.csv")

# %%
df['target'] = iris.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
x = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)']]

y = df['target']

# %% [markdown]
# ## Train test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42, stratify=y)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9777777777777777

# %%
from sklearn.linear_model import LogisticRegression

# %%
logis = LogisticRegression(C=1.0, penalty='l2', solver='lbfgs')

# %%
logis.fit(X_train, y_train)
# Out:
# c:\Users\tataa\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logis.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %% [markdown]
# ## Gimana kalau kita coba pakai cross validation ?

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
cv_scores_knn = cross_val_score(knn, X_train, y_train, cv=kf, scoring='accuracy')

# %%
cv_scores_knn.mean()
# Out:
# np.float64(0.9619047619047618)

# %%
cv_scored_logis = cross_val_score(logis,X_train,y_train,cv = kf, scoring="accuracy")

# %%
cv_scored_logis.mean()
# Out:
# np.float64(0.9619047619047618)
